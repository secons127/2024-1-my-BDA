# %% [markdown]
# <a href="https://colab.research.google.com/github/secons127/2024-1-my-BDA/blob/main/inclass/03w_240322_Fri_ch05_data_medium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**빅데이터분석프로그래밍**
#
# - B반 3주

# %% [markdown]
# #파이썬 설치 확인

# %%
import site
site.getsitepackages()
# Out:
# ['/usr/local/lib/python3.10/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3.10/dist-packages']

# %%
import sys
import pandas as pd
import numpy as np

print(sys.version)
print(pd.__version__)
print(np.__version__)
# Out:
# 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# 1.5.3
# 1.25.2

# %% [markdown]
# #그래프 해상도 설정

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.dpi' : '100'})
# %config InlineBackend.figure_format = 'retina'

# %%
# %%html
# <!--마크다운 표 정렬 설정-->
# <style> table {float:left} </style>

# %% [markdown]
# #코랩에서 한글 처리

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 23.7 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

plt.plot([-1, 0, 1, 2])
plt.title('그래프 제목', fontweight="bold")
plt.xlabel('간단한 그래프')
plt.show()

# %% [markdown]
# # 05 데이터 분석 기초! - 데이터 파악하기, 다루기 쉽게 수정하기
# ##05 - 1 데이터 파악하기
#
# 데이터를 파악할 때 사용하는 명령어

# %% [markdown]
# | 함수       | 기능               |
# |------------|--------------------|
# | head()     | 앞부분 출력        |
# | tail()     | 뒷부분 출력        |
# | shape      | 행, 열 개수 출력   |
# | info()     | 변수 속성 출력     |
# | describe() | 요약 통계량 출력   |

# %%
import pandas as pd
exam = pd.read_csv('exam.csv')

# %%
exam.head()  # 앞에서부터 5행까지 출력
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %%
exam.head(10)  # 앞에서부터 10행까지 출력
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25
# 8   9       3    20       98       15
# 9  10       3    50       98       45

# %%
exam.tail()  # 뒤에서부터 5행까지 출력
# Out:
#     id  nclass  math  english  science
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.tail(10)  # 뒤에서부터 10행까지 출력
# Out:
#     id  nclass  math  english  science
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# #### `shape` - 데이터가 몇 행, 몇 열로 구성되는지 알아보기

# %%
exam.shape
# Out:
# (20, 5)

# %% [markdown]
# #### `info()` - 속성 파악하기

# %%
exam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       20 non-null     int64
#  1   nclass   20 non-null     int64
#  2   math     20 non-null     int64
#  3   english  20 non-null     int64
#  4   science  20 non-null     int64
# dtypes: int64(5)
# memory usage: 928.0 bytes

# %% [markdown]
# #### `describe()` - 요약 통계량 구하기

# %%
exam.describe()
# Out:
#              id     nclass       math    english    science
# count  20.00000  20.000000  20.000000  20.000000  20.000000
# mean   10.50000   3.000000  57.450000  84.900000  59.450000
# std     5.91608   1.450953  20.299015  12.875517  25.292968
# min     1.00000   1.000000  20.000000  56.000000  12.000000
# 25%     5.75000   2.000000  45.750000  78.000000  45.000000
# 50%    10.50000   3.000000  54.000000  86.500000  62.500000
# 75%    15.25000   4.000000  75.750000  98.000000  78.000000
# max    20.00000   5.000000  90.000000  98.000000  98.000000

# %% [markdown]
# ### mpg 데이터 파악하기

# %%
import pandas as pd
# mpg 데이터 불러오기
mpg = pd.read_csv('mpg.csv')

# %%
mpg.head()  # mpg 앞부분 확인
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
mpg.tail()  # mpg 뒷부분 확인
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize

# %%
mpg.shape  # 행, 열 출력
# Out:
# (234, 11)

# %%
mpg.info()  # 데이터 속성 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
mpg.describe()  # 요약 통계량 출력
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
mpg.describe(include = 'all')  # 문자 변수 요약 통계량 함께 출력
# Out:
#        manufacturer        model       displ         year         cyl  \
# count           234          234  234.000000   234.000000  234.000000
# unique           15           38         NaN          NaN         NaN
# top           dodge  caravan 2wd         NaN          NaN         NaN
# freq             37           11         NaN          NaN         NaN
# mean            NaN          NaN    3.471795  2003.500000    5.888889
# std             NaN          NaN    1.291959     4.509646    1.611534
# min             NaN          NaN    1.600000  1999.000000    4.000000
# 25%             NaN          NaN    2.400000  1999.000000    4.000000
# 50%             NaN          NaN    3.300000  2003.500000    6.000000
# 75%             NaN          NaN    4.600000  2008.000000    8.000000
# max             NaN          NaN    7.000000  2008.000000    8.000000
#
#            trans  drv         cty         hwy   fl category
# count        234  234  234.000000  234.000000  234      234
# ...

# %%
mpg.describe(include = 'all')[["manufacturer", "model", "trans", "drv", "fl", "category"]]
#결과가 데이터 프레임 >> []
# Out:
#        manufacturer        model     trans  drv   fl category
# count           234          234       234  234  234      234
# unique           15           38        10    3    5        7
# top           dodge  caravan 2wd  auto(l4)    f    r      suv
# freq             37           11        83  106  168       62
# mean            NaN          NaN       NaN  NaN  NaN      NaN
# std             NaN          NaN       NaN  NaN  NaN      NaN
# min             NaN          NaN       NaN  NaN  NaN      NaN
# 25%             NaN          NaN       NaN  NaN  NaN      NaN
# 50%             NaN          NaN       NaN  NaN  NaN      NaN
# 75%             NaN          NaN       NaN  NaN  NaN      NaN
# max             NaN          NaN       NaN  NaN  NaN      NaN

# %%
mpg[["manufacturer", "model", "trans", "drv", "fl", "category"]].describe()
# Out:
#        manufacturer        model     trans  drv   fl category
# count           234          234       234  234  234      234
# unique           15           38        10    3    5        7
# top           dodge  caravan 2wd  auto(l4)    f    r      suv
# freq             37           11        83  106  168       62

# %%
mpg.fl.unique() # 연료 종류
# Out:
# array(['p', 'r', 'e', 'd', 'c'], dtype=object)

# %%
mpg["fl"].unique() # 연료 종류
# Out:
# array(['p', 'r', 'e', 'd', 'c'], dtype=object)

# %%
mpg.fl.value_counts()
# Out:
# r    168
# p     52
# e      8
# d      5
# c      1
# Name: fl, dtype: int64

# %%
mpg.fl.value_counts().sort_index()
# Out:
# c      1
# d      5
# e      8
# p     52
# r    168
# Name: fl, dtype: int64

# %%
mpg.trans.unique() # 트랜스미션 종류
# Out:
# array(['auto(l5)', 'manual(m5)', 'manual(m6)', 'auto(av)', 'auto(s6)',
#        'auto(l4)', 'auto(l3)', 'auto(l6)', 'auto(s5)', 'auto(s4)'],
#       dtype=object)

# %%
mpg.trans.value_counts()
# Out:
# auto(l4)      83
# manual(m5)    58
# auto(l5)      39
# manual(m6)    19
# auto(s6)      16
# auto(l6)       6
# auto(av)       5
# auto(s5)       3
# auto(s4)       3
# auto(l3)       2
# Name: trans, dtype: int64

# %%
mpg.manufacturer.unique()
# Out:
# array(['audi', 'chevrolet', 'dodge', 'ford', 'honda', 'hyundai', 'jeep',
#        'land rover', 'lincoln', 'mercury', 'nissan', 'pontiac', 'subaru',
#        'toyota', 'volkswagen'], dtype=object)

# %%
mpg.manufacturer.value_counts()
# Out:
# dodge         37
# toyota        34
# volkswagen    27
# ford          25
# chevrolet     19
# audi          18
# hyundai       14
# subaru        14
# nissan        13
# honda          9
# jeep           8
# pontiac        5
# land rover     4
# mercury        4
# lincoln        3
# Name: manufacturer, dtype: int64

# %%
mpg.drv.unique()
# Out:
# array(['f', '4', 'r'], dtype=object)

# %%
mpg.drv.value_counts()
# Out:
# f    106
# 4    103
# r     25
# Name: drv, dtype: int64

# %% [markdown]
# ### 함수와 메서드 차이 알아보기

# %% [markdown]
# **(1) 내장 함수**

# %%
sum([5, 7, 2])
# Out:
# 14

# %%
max(5, 7, 2)
# Out:
# 7

# %%
max([5, 7, 2])
# Out:
# 7

# %% [markdown]
# **(2) 패키지 함수**

# %%
import pandas as pd
# pd.read_csv('exam.csv')
df = pd.DataFrame({'x' : [1, 2, 3]})

# %% [markdown]
# **(3) 메서드**

# %%
df.head()
# Out:
#    x
# 0  1
# 1  2
# 2  3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       3 non-null      int64
# dtypes: int64(1)
# memory usage: 152.0 bytes

# %%
df.head()  # 메서드
# Out:
#    x
# 0  1
# 1  2
# 2  3

# %%
df.shape   # 어트리뷰트
# Out:
# (3, 1)

# %% [markdown]
# ---
# ## 05-2 변수명 바꾸기
# **(p.113: 중요함 / 중간고사에 나옴)**

# %%
df_raw = pd.DataFrame({'var1' : [1, 2, 1],
                       'var2' : [2, 3, 2]})
df_raw
# Out:
#    var1  var2
# 0     1     2
# 1     2     3
# 2     1     2

# %% [markdown]
# #### 2. 데이터 프레임 복사본 만들기

# %%
df_new = df_raw.copy()  # 복사본 만들기
df_new                  # 출력
# Out:
#    var1  var2
# 0     1     2
# 1     2     3
# 2     1     2

# %% [markdown]
# #### 3. 변수명 바꾸기

# %%
df_new = df_new.rename(columns = {'var2' : 'v2'})  # var2를 v2로 수정(시험)
df_new
# Out:
#    var1  v2
# 0     1   2
# 1     2   3
# 2     1   2

# %%
df_new.rename(index = {0: "x", 1: "y", 2: "z"}) # 행 이름 수정(시험)
# Out:
#    var1  v2
# x     1   2
# y     2   3
# z     1   2

# %%
df_raw
# Out:
#    var1  var2
# 0     1     2
# 1     2     3
# 2     1     2

# %%
df_new
# Out:
#    var1  v2
# 0     1   2
# 1     2   3
# 2     1   2

# %% [markdown]
# ---
# ## 05-3 파생변수 만들기

# %% [markdown]
# ### 변수 조합해 파생변수 만들기

# %%
df = pd.DataFrame({'var1' : [4, 3, 8],
                   'var2' : [2, 6, 1]})
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1 = df.copy()
df1
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1['var_sum'] = df1['var1'] + df1['var2']  # var_sum 파생변수 만들기
df1
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df1['var_mean'] = (df1['var1'] + df1['var2']) / 2  # var_mean 파생변수 만들기
df1
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %%
df2 = df.copy()
df2
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
#새로운 열 var_mean <- var1과 var2dml 평균
df1['var1'] = df1["var1"]+df2["var2"] /2
df1
# Out:
#    var1  var2  var_sum  var_mean
# 0   5.0     2        6       3.0
# 1   6.0     6        9       4.5
# 2   8.5     1        9       4.5

# %%
#새로운 열 var_mean <- var1과 var2dml 평균
df2["my_mean"] = df2[["var1","var2"]].mean(axis=1)
df2
# Out:
#    var1  var2  my_sum  my_mean
# 0     4     2       6      3.0
# 1     3     6       9      4.5
# 2     8     1       9      4.5

# %%
df2.sum(axis=1)
# Out:
# 0    6
# 1    9
# 2    9
# dtype: int64

# %%
df2['my_sum'] = df2.sum(axis=1)
df2
# Out:
#    var1  var2  my_sum
# 0     4     2       6
# 1     3     6       9
# 2     8     1       9

# %%
df2['my_mean'] = df2[["var1", "var2"]].mean(axis=1)
df2
# Out:
#    var1  var2  my_sum  my_mean
# 0     4     2       6      3.0
# 1     3     6       9      4.5
# 2     8     1       9      4.5

# %% [markdown]
# ### mpg 통합 연비 변수 만들기

# %%
# mpg 데이터 불러오기
mpg = pd.read_csv('mpg.csv')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
mpg['total'] = (mpg['cty'] + mpg['hwy']) / 2  # 통합 연비 변수 만들기
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total
# 0   23.5
# 1   25.0
# 2   25.5
# 3   25.5
# 4   21.0

# %%
mpg['mpg_mean'] = mpg[['cty', 'hwy']].mean(axis='columns')  # 통합 연비 변수 만들기
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total  mpg_mean
# 0   23.5      23.5
# 1   25.0      25.0
# 2   25.5      25.5
# 3   25.5      25.5
# 4   21.0      21.0

# %%
sum(mpg['total']) / len(mpg)  # total 합계를 행 수로 나누기
# Out:
# 20.14957264957265

# %%
# 출처: https://rfriend.tistory.com/487 [R, Python 분석과 프로그래밍의 친구 (by R Friend):티스토리]

from IPython.core.display import display, HTML
display(HTML("<style>.container { width: 50% !important; }</style>"))

# pd.set_option('display.float_format', '{:,.2f}'.format)
# Out:
# <style>.container { width: 50% !important; }</style>

# %%
mpg['total'].mean()  # 통합 연비 변수 평균
# Out:
# 20.14957264957265

# %% [markdown]
# ### 조건문을 활용해 파생변수 만들기

# %% [markdown]
# #### 1. 기준값 정하기

# %%
mpg['total'].describe()  # 요약 통계량 출력
# Out:
# count    234.000000
# mean      20.149573
# std        5.050290
# min       10.500000
# 25%       15.500000
# 50%       20.500000
# 75%       23.500000
# max       39.500000
# Name: total, dtype: float64

# %%
# 그래프 만들기
mpg['total'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
mpg['total'].plot(kind="hist", title="히스토그램");

# %%
import seaborn as sns

sns.histplot(mpg, x="total"); # x=mpg.total

# %%
sns.histplot?

# %% [markdown]
# #### 2. 합격 판정 변수 만들기 120p

# %%
import numpy as np

# 20 이상이면 pass, 그렇지 않으면 fail 부여
mpg['test'] = np.where(mpg['total'] >= 20, 'pass', 'fail')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total  mpg_mean  test
# 0   23.5      23.5  pass
# 1   25.0      25.0  pass
# 2   25.5      25.5  pass
# 3   25.5      25.5  pass
# 4   21.0      21.0  pass

# %% [markdown]
# #### 3. 빈도표로 합격 판정 자동차 수 살펴보기

# %%
mpg['test'].value_counts()  # 연비 합격 빈도표 만들기
# Out:
# pass    128
# fail    106
# Name: test, dtype: int64

# %%
mpg['test'].unique()
# Out:
# array(['pass', 'fail'], dtype=object)

# %% [markdown]
# #### 4. 막대 그래프로 빈도 표현하기

# %%
count_test = mpg['test'].value_counts()  # 연비 합격 빈도표를 변수에 할당

# %%
type(count_test)
# Out:
# pandas.core.series.Series

# %%
count_test.plot.bar()  # 연비 합격 빈도 막대 그래프 만들기
# Out:
# <Axes: >

# %% [markdown]
# #### 축 이름 회전하기

# %%
count_test.plot.bar(rot = 0);  # 축 이름 수평으로 만들기

# %%
sns.countplot(mpg, x="test", hue=mpg.test);

# %%
sns.countplot(mpg, x="test", hue=mpg.test);

# %%
sns.countplot(mpg, x='test', hue="cyl", stat= "percent");

# %% [markdown]
# ### 중첩 조건문 활용하기

# %% [markdown]
# #### 1. 연비 등급 변수 만들기

# %%
# total 기준으로 A, B, C 등급 부여
mpg['grade'] = np.where(mpg['total'] >= 30, 'A',
               np.where(mpg['total'] >= 20, 'B', 'C'))

# 데이터 확인
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total  mpg_mean  test grade
# 0   23.5      23.5  pass     B
# 1   25.0      25.0  pass     B
# 2   25.5      25.5  pass     B
# 3   25.5      25.5  pass     B
# 4   21.0      21.0  pass     B

# %% [markdown]
# #### 2. 빈도표와 막대 그래프로 연비 등급 살펴보기

# %%
count_grade = mpg['grade'].value_counts()  # 등급 빈도표 만들기
count_grade
# Out:
# B    118
# C    106
# A     10
# Name: grade, dtype: int64

# %%
count_grade.plot.bar(rot = 0)  # 등급 빈도 막대 그래프 만들기
# Out:
# <Axes: >

# %%
sns.countplot(mpg, x="grade", hue="grade")
# Out:
# <Axes: xlabel='grade', ylabel='count'>

# %%
sns.countplot(mpg, x="grade", hue="grade", stat='percent');

# %% [markdown]
# #### 알파벳순으로 막대 정렬하기

# %%
# 등급 빈도표 알파벳순 정렬
count_grade = mpg['grade'].value_counts().sort_index()
count_grade
# Out:
# A     10
# B    118
# C    106
# Name: grade, dtype: int64

# %%
count_grade.index
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
# 등급 빈도 막대 그래프 만들기
count_grade.plot.bar(rot = 0)
# Out:
# <Axes: >

# %%
sns.countplot(mpg, x="grade", hue="grade", stat='percent', order=["A", "B", "C"]);

# %%
sns.countplot(mpg, x="grade", hue="grade", order=mpg['grade'].value_counts().sort_index().index)
# Out:
# <Axes: xlabel='grade', ylabel='count'>

# %%
import numpy as np
np.sort(mpg['grade'].unique())
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %%
sns.countplot(mpg, x="grade", hue="grade", order=np.sort(mpg['grade'].unique()));

# %% [markdown]
# ---
#
# ### (알아 두면 좋아요) 메서드 체이닝

# %%
# 출력 결과를 변수에 할당하는 방법
df = mpg['grade']
df = df.value_counts()
df = df.sort_index()
type(df)
# Out:
# pandas.core.series.Series

# %%
# 메서드 체이닝
s = mpg['grade'].value_counts().sort_index()
s
# Out:
# A     10
# B    118
# C    106
# Name: grade, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# #### 필요한 만큼 범주 만들기

# %%
# A, B, C, D 등급 변수 만들기
mpg['grade2'] = np.where(mpg['total'] >= 30, 'A',
                np.where(mpg['total'] >= 25, 'B',
                np.where(mpg['total'] >= 20, 'C', 'D')))
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4   1.80  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4   1.80  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4   2.00  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4   2.00  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4   2.80  1999    6    auto(l5)   f   16   26  p  compact
#
#    total  mpg_mean  test grade grade2
# 0  23.50     23.50  pass     B      C
# 1  25.00     25.00  pass     B      B
# 2  25.50     25.50  pass     B      B
# 3  25.50     25.50  pass     B      B
# 4  21.00     21.00  pass     B      C

# %% [markdown]
# ### 목록에 해당하는 행으로 변수 만들기

# %%
mpg['size'] = np.where((mpg['category'] == 'compact') |
                       (mpg['category'] == 'subcompact') |
                       (mpg['category'] == '2seater'),
                       'small', 'large')

mpg['size'].value_counts()
# Out:
# large    147
# small     87
# Name: size, dtype: int64

# %%
mpg['size'] = np.where(mpg['category'].isin(['compact', 'subcompact', '2seater']), 'small', 'large') # 시험 문제

mpg['size'].value_counts()
# Out:
# large    147
# small     87
# Name: size, dtype: int64

# %% [markdown]
# ---
# ### 정리하기

# %%
# 1. 패키지 로드
import pandas as pd
import numpy as np

# 2. 데이터 불러오기
mpg = pd.read_csv('mpg.csv')

# 3. 데이터 파악하기
mpg.shape       # 행, 열 수
mpg.head()      # 데이터 앞부분
mpg.tail()      # 데이터 뒷부분
mpg.info()      # 속성
mpg.describe()  # 요약 통계량

# 4. 변수명 바꾸기
mpg = mpg.rename(columns = {'manufacturer' : 'company'})

# 5. 파생변수 만들기
mpg['total'] = (mpg['cty'] + mpg['hwy'])/2                  # 변수 조합
mpg['test'] = np.where(mpg['total'] >= 20, 'pass', 'fail')  # 조건문 활용

# 6. 빈도 확인하기
count_test = mpg['test'].value_counts()  # 빈도표 만들기
count_test.plot.bar(rot = 0)             # 빈도 막대 그래프 만들기
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB
# <Axes: >

# %%
sns.countplot(mpg, x='test', hue='test');  # 빈도표 만들기

# %%
sns.countplot(mpg, x='test', hue='test', stat='percent');  # 분포비율 만들기 /  시험 예상

# %% [markdown]
# ## 단원 5 종료

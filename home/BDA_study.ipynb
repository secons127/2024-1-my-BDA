# %% [markdown]
# <a href="https://colab.research.google.com/github/secons127/2024-1-my-BDA/blob/main/home/BDA_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.DataFrame({'name' : ['전성우','송상은','장민제','조성필'],
                   'english' :  [40,80,90,100],
                   'math':[80,80,90,100]})
# 인덱스를 1부터 시작하도록 설정
#df.index = df.index + 1

df
# Out:
#   name  english  math
# 1  전성우       40    80
# 2  송상은       80    80
# 3  장민제       90    90
# 4  조성필      100   100

# %%
df['english']
# Out:
# 1     40
# 2     80
# 3     90
# 4    100
# Name: english, dtype: int64

# %%
sum(df['english'])
# Out:
# 310

# %%
sum(df['math'])
# Out:
# 350

# %%
sum(df['english']) / 4
# Out:
# 77.5

# %%
sum(df['math']) / 4
# Out:
# 87.5

# %% [markdown]
# **#1**

# %%
sales = pd.DataFrame({'fruit': ['사과','딸기','수박'],
              'price': [1800,1500,3000],
              'volume': [24,38,13]})
sales
# Out:
#   fruit  price  volume
# 0    사과   1800      24
# 1    딸기   1500      38
# 2    수박   3000      13

# %%
sum(sales['price']) / 3
# Out:
# 2100.0

# %%
sum(sales['volume']) / 3
# Out:
# 25.0
